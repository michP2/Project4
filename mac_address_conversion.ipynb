# %%
mac= '00:34:ef:2e:f4'
mac
# Out:
# '00:34:ef:2e:f4'

# %%
n= int(mac.replace(':',''), 16)
print(n)
# Out:
# 888090356

# %%
mac= '00:84:cd:2a:b3'
mac
# Out:
# '00:84:cd:2a:b3'

# %%
s= int(mac.replace(':',''), 16)
print(s)
# Out:
# 2228038323

# %%
def conv(mac_addr):
    return ':'.join('%02x'% ord(b) for b in mac_addr)

conv(b'2228038323')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-8c5a1c5d72de> in <module>()
#       2     return ':'.join('%02x'% ord(b) for b in mac_addr)
#       3
# ----> 4 conv(b'2228038323')
#
# <ipython-input-6-8c5a1c5d72de> in conv(mac_addr)
#       1 def conv(mac_addr):
# ----> 2     return ':'.join('%02x'% ord(b) for b in mac_addr)
#       3
#       4 conv(b'2228038323')
#
# <ipython-input-6-8c5a1c5d72de> in <genexpr>(.0)
#       1 def conv(mac_addr):
# ----> 2     return ':'.join('%02x'% ord(b) for b in mac_addr)
#       3
#       4 conv(b'2228038323')
#
# TypeError: ord() expected string of length 1, but int found

# %%
def conv(mac_addr):
    return ':'.join('%02x'% ord(b) for b in mac_addr)

conv(b '2228038323')
# Out:
#   File "<ipython-input-7-739bea3ce101>", line 4
#     conv(b '2228038323')
#                       ^
# SyntaxError: invalid syntax

# %%
def conv(mac_addr):
    return ':'.join('%02x'% ord(b) for b in mac_addr)

conv(b'6f\x21\x00s3')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-97130d38103d> in <module>()
#       2     return ':'.join('%02x'% ord(b) for b in mac_addr)
#       3
# ----> 4 conv(b'6f\x21\x00s3')
#
# <ipython-input-8-97130d38103d> in conv(mac_addr)
#       1 def conv(mac_addr):
# ----> 2     return ':'.join('%02x'% ord(b) for b in mac_addr)
#       3
#       4 conv(b'6f\x21\x00s3')
#
# <ipython-input-8-97130d38103d> in <genexpr>(.0)
#       1 def conv(mac_addr):
# ----> 2     return ':'.join('%02x'% ord(b) for b in mac_addr)
#       3
#       4 conv(b'6f\x21\x00s3')
#
# TypeError: ord() expected string of length 1, but int found

# %%
def conv(mac_addr):
    return ':'.join('%02x'% ord(b) for b in mac_addr)

conv(b '6f\x21\x00s3')
# Out:
#   File "<ipython-input-9-c2141ebe3fa7>", line 4
#     conv(b '6f\x21\x00s3')
#                         ^
# SyntaxError: invalid syntax

# %%
addr = '6f\x21\x00s3'
addr
# Out:
# '6f!\x00s3'

# %%
for i in addr:
    print('%02x',(i))
# Out:
# %02x 6
# %02x f
# %02x !
# %02x
# %02x s
# %02x 3

# %%
def conv(mac_addr):
    for b in mac_addr:
        print('%02x'(b))

conv(b '6f\x21\x00s3')
# Out:
#   File "<ipython-input-12-40ea0ca47a10>", line 5
#     conv(b '6f\x21\x00s3')
#                         ^
# SyntaxError: invalid syntax

# %%
def conv(mac_addr):
    for b in mac_addr:
        print('%02x:' % (b))

conv(b'6f\x21\x00s3')
# Out:
# 36:
# 66:
# 21:
# 00:
# 73:
# 33:

# %%
def conv(mac_addr):
    for i in mac_addr:
        a=('%02x:' % (i))
        print(a)

conv(i'6f\x21\x00s3')
# Out:
#   File "<ipython-input-41-e2826dcf007c>", line 6
#     conv(i'6f\x21\x00s3')
#                        ^
# SyntaxError: invalid syntax

# %%
def conv(mac_addr):
    for b in mac_addr:
        a=('%02x:' % (b))
        print(a)

conv(b'6f\x21\x00s3')
# Out:
# 36:
# 66:
# 21:
# 00:
# 73:
# 33:

# %%
def conv(mac_addr):
    for b in mac_addr:
        a=('%02x:' % (b))
        print(a,end=':')

conv(b'6f\x21\x00s3')
# Out:
# 36::66::21::00::73::33::

# %%
def conv(mac_addr):
    for b in mac_addr:
        a=('%02x' % (b))
        print(a)

conv(b'6f\x21\x00s3')
# Out:
# 36
# 66
# 21
# 00
# 73
# 33

# %%
':'.join(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-027a2caed837> in <module>()
# ----> 1 ':'.join(a)
#
# NameError: name 'a' is not defined

# %%
def conv(mac_addr):
    for b in mac_addr:
        a=('%02x' % (b))
        print(a,end=':')

conv(b'6f\x21\x00s3')
# Out:
# 36:66:21:00:73:33:

# %%
def conv(mac_addr):
    for b in mac_addr:
        a=('%02x' % (b))
        result= a
print(result)

conv(b'6f\x21\x00s3')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-0eed7e9cd5c6> in <module>()
#       3         a=('%02x' % (b))
#       4         result= a
# ----> 5 print(result)
#       6
#       7 conv(b'6f\x21\x00s3')
#
# NameError: name 'result' is not defined

# %%
def conv(mac_addr):
    for b in mac_addr:
        a=('%02x' % (b))
        return a
print(a)

conv(b'6f\x21\x00s3')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-3d4bfd7bb49d> in <module>()
#       3         a=('%02x' % (b))
#       4         return a
# ----> 5 print(a)
#       6
#       7 conv(b'6f\x21\x00s3')
#
# NameError: name 'a' is not defined

# %%
def conv(mac_addr):
    for b in mac_addr:
        a=('%02x' % (b))
        result=a
        print(result)

conv(b'6f\x21\x00s3')
# Out:
# 36
# 66
# 21
# 00
# 73
# 33

# %%
mac_address=':'.join(result)

# %%
mac_address=':'.join(result)

# %%
def conv(mac_addr):
    for b in mac_addr:
        a=('%02x' % (b))
        result=a
        print(result)

conv(b'6f\x21\x00s3')
# Out:
# 36
# 66
# 21
# 00
# 73
# 33

# %%
mac_address=':'.join(result)
